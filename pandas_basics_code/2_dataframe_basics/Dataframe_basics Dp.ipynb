# %%
import pandas as pd

# %%
df=pd.read_csv("movies.csv")
df.head(3)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English

# %%
df.tail(3)
# Out:
#                         title   industry  release_year  imdb_rating  \
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
df.shape
# Out:
# (37, 10)

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
df.industry.unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df.language.value_counts()
# Out:
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: language, dtype: int64

# %%
df[["title","industry","imdb_rating"]]
# Out:
#                                           title   industry  imdb_rating
# 0                               Pather Panchali  Bollywood          8.3
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          7.0
# 2                         Thor: The Dark World   Hollywood          6.8
# 3                               Thor: Ragnarok   Hollywood          7.9
# 4                       Thor: Love and Thunder   Hollywood          6.8
# 5                      The Shawshank Redemption  Hollywood          9.3
# 6                                  Interstellar  Hollywood          8.6
# 7                      The Pursuit of Happyness  Hollywood          8.0
# 8                                     Gladiator  Hollywood          8.5
# 9                                       Titanic  Hollywood          7.9
# 10                        It's a Wonderful Life  Hollywood          8.6
# 11                                       Avatar  Hollywood          7.8
# 12                                The Godfather  Hollywood          9.2
# 13                              The Dark Knight  Hollywood          9.0
# 14                             Schindler's List  Hollywood          9.0
# 15                                Jurassic Park  Hollywood          8.2
# 16                                     Parasite  Hollywood          8.5
# 17                            Avengers: Endgame  Hollywood          8.4
# 18                       Avengers: Infinity War  Hollywood          8.4
# 19           Captain America: The First Avenger  Hollywood          6.9
# 20          Captain America: The Winter Soldier  Hollywood          7.8
# 21                  Dilwale Dulhania Le Jayenge  Bollywood          8.0
# 22                                     3 Idiots  Bollywood          8.4
# 23                     Kabhi Khushi Kabhie Gham  Bollywood          7.4
# 24                             Bajirao Mastani   Bollywood          7.2
# 25                             Taare Zameen Par  Bollywood          8.3
# 26                          Munna Bhai M.B.B.S.  Bollywood          8.1
# 27                                           PK  Bollywood          8.1
# 28                                        Sanju  Bollywood          NaN
# 29                            The Kashmir Files  Bollywood          8.3
# 30                            Bajrangi Bhaijaan  Bollywood          8.1
# 31                                       Race 3  Bollywood          1.9
# 32                                    Shershaah  Bollywood          8.4
# 33                             K.G.F: Chapter 2  Bollywood          8.4
# 34                    Pushpa: The Rise - Part 1  Bollywood          7.6
# 35                                          RRR  Bollywood          8.0
# 36                     Baahubali: The Beginning  Bollywood          8.0

# %%
df_new = df[["title","industry","imdb_rating"]]
df_new
# Out:
#                                           title   industry  imdb_rating
# 0                               Pather Panchali  Bollywood          8.3
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          7.0
# 2                         Thor: The Dark World   Hollywood          6.8
# 3                               Thor: Ragnarok   Hollywood          7.9
# 4                       Thor: Love and Thunder   Hollywood          6.8
# 5                      The Shawshank Redemption  Hollywood          9.3
# 6                                  Interstellar  Hollywood          8.6
# 7                      The Pursuit of Happyness  Hollywood          8.0
# 8                                     Gladiator  Hollywood          8.5
# 9                                       Titanic  Hollywood          7.9
# 10                        It's a Wonderful Life  Hollywood          8.6
# 11                                       Avatar  Hollywood          7.8
# 12                                The Godfather  Hollywood          9.2
# 13                              The Dark Knight  Hollywood          9.0
# 14                             Schindler's List  Hollywood          9.0
# 15                                Jurassic Park  Hollywood          8.2
# 16                                     Parasite  Hollywood          8.5
# 17                            Avengers: Endgame  Hollywood          8.4
# 18                       Avengers: Infinity War  Hollywood          8.4
# 19           Captain America: The First Avenger  Hollywood          6.9
# 20          Captain America: The Winter Soldier  Hollywood          7.8
# 21                  Dilwale Dulhania Le Jayenge  Bollywood          8.0
# 22                                     3 Idiots  Bollywood          8.4
# 23                     Kabhi Khushi Kabhie Gham  Bollywood          7.4
# 24                             Bajirao Mastani   Bollywood          7.2
# 25                             Taare Zameen Par  Bollywood          8.3
# 26                          Munna Bhai M.B.B.S.  Bollywood          8.1
# 27                                           PK  Bollywood          8.1
# 28                                        Sanju  Bollywood          NaN
# 29                            The Kashmir Files  Bollywood          8.3
# 30                            Bajrangi Bhaijaan  Bollywood          8.1
# 31                                       Race 3  Bollywood          1.9
# 32                                    Shershaah  Bollywood          8.4
# 33                             K.G.F: Chapter 2  Bollywood          8.4
# 34                    Pushpa: The Rise - Part 1  Bollywood          7.6
# 35                                          RRR  Bollywood          8.0
# 36                     Baahubali: The Beginning  Bollywood          8.0

# %%
df[(df.release_year>=2000) & (df.release_year<=2010)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 8                  Gladiator  Hollywood          2000          8.5
# 11                    Avatar  Hollywood          2009          7.8
# 13           The Dark Knight  Hollywood          2008          9.0
# 22                  3 Idiots  Bollywood          2009          8.4
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 25          Taare Zameen Par  Bollywood          2007          8.3
# 26       Munna Bhai M.B.B.S.  Bollywood          2003          8.1
#
#                       studio  budget  revenue      unit currency language
# 7          Columbia Pictures    55.0    307.1  Millions      USD  English
# 8       Universal Pictures     103.0    460.5  Millions      USD  English
# 11          20th Century Fox   237.0   2847.0  Millions      USD  English
# 13                   Syncopy   185.0   1006.0  Millions      USD  English
# 22        Vinod Chopra Films   550.0   4000.0  Millions      INR    Hindi
# 23        Dharma Productions   390.0   1360.0  Millions      INR    Hindi
# 25                       NaN   120.0   1350.0  Millions      INR    Hindi
# 26  Vinod Chopra Productions   100.0    410.0  Millions      INR    Hindi

# %%
df.studio.unique()
# Out:
# array(['Government of West Bengal', 'Marvel Studios',
#        'Castle Rock Entertainment', 'Warner Bros. Pictures',
#        'Columbia Pictures', 'Universal Pictures  ', 'Paramount Pictures',
#        'Liberty Films', '20th Century Fox', 'Syncopy',
#        'Universal Pictures', nan, 'Yash Raj Films', 'Vinod Chopra Films',
#        'Dharma Productions', 'Vinod Chopra Productions', 'Zee Studios',
#        'Salman Khan Films', 'Hombale Films', 'Mythri Movie Makers',
#        'DVV Entertainment', 'Arka Media Works'], dtype=object)

# %%
df[df.studio == "Marvel Studios"]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# 4           6.8  Marvel Studios   250.0    670.0  Millions      USD  English
# 17          8.4  Marvel Studios   400.0   2798.0  Millions      USD  English
# 18          8.4  Marvel Studios   400.0   2048.0  Millions      USD  English
# 19          6.9  Marvel Studios   216.7    370.6  Millions      USD  English
# 20          7.8  Marvel Studios   177.0    714.4  Millions      USD  English

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.describe()
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:10265, in NDFrame.describe(self, percentiles, include, exclude)
#   10262     return describe_1d(self)
#   10263 elif (include is None) and (exclude is None):
#   10264     # when some numerics are found, keep only numerics
# > 10265     data = self.select_dtypes(include=[np.number])
#   10266     if len(data.columns) == 0:
#   10267         data = self
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:3442, in DataFrame.select_dtypes(self, include, exclude)
#    3425     raise ValueError(
#    3426         "include and exclude overlap on {inc_ex}".format(
#    3427             inc_ex=(include & exclude)
#    3428         )
#    3429     )
#    3431 # empty include/exclude -> defaults to True
#    3432 # three cases (we've already raised if both are empty)
#    3433 # case 1: empty include, nonempty exclude
#    (...)
#    3440 # the "union" of the logic of case 1 and case 2:
#    3441 # we get the included and excluded, and return their logical and
# -> 3442 include_these = Series(not bool(include), index=self.columns)
#    3443 exclude_these = Series(not bool(exclude), index=self.columns)
#    3445 def is_dtype_instance_mapper(idx, dtype):
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py:314, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     312             data = data.copy()
#     313     else:
# --> 314         data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     316         data = SingleBlockManager(data, index, fastpath=True)
#     318 generic.NDFrame.__init__(self, data, fastpath=True)
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py:712, in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     708     else:
#     709         # need to possibly convert the value here
#     710         value = maybe_cast_to_datetime(value, dtype)
# --> 712     subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     714 else:
#     715     return subarr.item()
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\dtypes\cast.py:1233, in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1230         if not isna(value):
#    1231             value = ensure_str(value)
# -> 1233     subarr = np.empty(length, dtype=dtype)
#    1234     subarr.fill(value)
#    1236 return subarr
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(df.info())
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:2572, in DataFrame.info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2570         if "object" in counts or self.index._is_memory_usage_qualified():
#    2571             size_qualifier = "+"
# -> 2572     mem_usage = self.memory_usage(index=True, deep=deep).sum()
#    2573     lines.append(
#    2574         "memory usage: {mem}\n".format(
#    2575             mem=_sizeof_fmt(mem_usage, size_qualifier)
#    2576         )
#    2577     )
#    2579 fmt.buffer_put_lines(buf, lines)
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:2670, in DataFrame.memory_usage(self, index, deep)
#    2665 result = Series(
#    2666     [c.memory_usage(index=False, deep=deep) for col, c in self.items()],
#    2667     index=self.columns,
#    2668 )
#    2669 if index:
# -> 2670     result = Series(self.index.memory_usage(deep=deep), index=["Index"]).append(
#    2671         result
#    2672     )
#    2673 return result
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py:314, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     312             data = data.copy()
#     313     else:
# --> 314         data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     316         data = SingleBlockManager(data, index, fastpath=True)
#     318 generic.NDFrame.__init__(self, data, fastpath=True)
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\construction.py:712, in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     708     else:
#     709         # need to possibly convert the value here
#     710         value = maybe_cast_to_datetime(value, dtype)
# --> 712     subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     714 else:
#     715     return subarr.item()
#
# File c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\dtypes\cast.py:1233, in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1230         if not isna(value):
#    1231             value = ensure_str(value)
# -> 1233     subarr = np.empty(length, dtype=dtype)
#    1234     subarr.fill(value)
#    1236 return subarr
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
df.imdb_rating.max()
# Out:
# 9.3

# %%
df[df.imdb_rating == df.imdb_rating.max()]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df[(df.imdb_rating==df.imdb_rating.max())| (df.imdb_rating==df.imdb_rating.min())]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %%
df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# 3      USD  English

# %%
df["age"] = df["release_year"].apply(lambda x: 2024 - x)
df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language  age
# 0      INR  Bengali   69
# 1      USD  English    2
# 2      USD  English   11
# 3      USD  English    7

# %%
df["profit"] = df.apply (lambda x: x['revenue'] - x['budget'], axis=1 )
df.head(4)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
#
#   currency language  age   profit
# 0      INR  Bengali   69  30000.0
# 1      USD  English    2    754.8
# 2      USD  English   11    479.8
# 3      USD  English    7    674.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %%
print(df.columns)
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language', 'age', 'profit'],
#       dtype='object')

# %%
df.set_index("title", inplace=True)

# %%
df.index
# Out:
# Index(['Pather Panchali', 'Doctor Strange in the Multiverse of Madness',
#        'Thor: The Dark World ', 'Thor: Ragnarok ', 'Thor: Love and Thunder ',
#        'The Shawshank Redemption', 'Interstellar', 'The Pursuit of Happyness',
#        'Gladiator', 'Titanic', 'It's a Wonderful Life', 'Avatar',
#        'The Godfather', 'The Dark Knight', 'Schindler's List', 'Jurassic Park',
#        'Parasite', 'Avengers: Endgame', 'Avengers: Infinity War',
#        'Captain America: The First Avenger',
#        'Captain America: The Winter Soldier', 'Dilwale Dulhania Le Jayenge',
#        '3 Idiots', 'Kabhi Khushi Kabhie Gham', 'Bajirao Mastani ',
#        'Taare Zameen Par', 'Munna Bhai M.B.B.S.', 'PK', 'Sanju',
#        'The Kashmir Files', 'Bajrangi Bhaijaan', 'Race 3', 'Shershaah',
#        'K.G.F: Chapter 2', 'Pushpa: The Rise - Part 1', 'RRR',
#        'Baahubali: The Beginning'],
#       dtype='object', name='title')

# %%
df.head(3)
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# Doctor Strange in the Multiverse of Madness             Marvel Studios
# Thor: The Dark World                                    Marvel Studios
#
#                                               budget   revenue       unit  \
# title
# Pather Panchali                              70000.0  100000.0  Thousands
# Doctor Strange in the Multiverse of Madness    200.0     954.8   Millions
# Thor: The Dark World                           165.0     644.8   Millions
#
#                                             currency language  age   profit
# title
# Pather Panchali                                  INR  Bengali   69  30000.0
# Doctor Strange in the Multiverse of Madness      USD  English    2    754.8
# Thor: The Dark World                             USD  English   11    479.8

# %%
df.loc["Pather Panchali"]
# Out:
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                              70000
# revenue                            100000
# unit                            Thousands
# currency                              INR
# language                          Bengali
# age                                    69
# profit                              30000
# Name: Pather Panchali, dtype: object

# %%
df.loc["K.G.F: Chapter 2"]
# Out:
# industry            Bollywood
# release_year             2022
# imdb_rating               8.4
# studio          Hombale Films
# budget                      1
# revenue                  12.5
# unit                 Billions
# currency                  INR
# language              Kannada
# age                         2
# profit                   11.5
# Name: K.G.F: Chapter 2, dtype: object

# %%
df.loc["The Pursuit of Happyness"]
# Out:
# industry                Hollywood
# release_year                 2006
# imdb_rating                     8
# studio          Columbia Pictures
# budget                         55
# revenue                     307.1
# unit                     Millions
# currency                      USD
# language                  English
# age                            18
# profit                      252.1
# Name: The Pursuit of Happyness, dtype: object

# %%
df.loc[['Titanic', 'Avatar',
       'The Godfather', 'The Dark Knight', 'Jurassic Park',
       'Parasite', 'Avengers: Endgame']]
# Out:
#                     industry  release_year  imdb_rating              studio  \
# title
# Titanic            Hollywood          1997          7.9  Paramount Pictures
# Avatar             Hollywood          2009          7.8    20th Century Fox
# The Godfather      Hollywood          1972          9.2  Paramount Pictures
# The Dark Knight    Hollywood          2008          9.0             Syncopy
# Jurassic Park      Hollywood          1993          8.2  Universal Pictures
# Parasite           Hollywood          2019          8.5                 NaN
# Avengers: Endgame  Hollywood          2019          8.4      Marvel Studios
#
#                    budget  revenue      unit currency language  age  profit
# title
# Titanic             200.0   2202.0  Millions      USD  English   27  2002.0
# Avatar              237.0   2847.0  Millions      USD  English   15  2610.0
# The Godfather         7.2    291.0  Millions      USD  English   52   283.8
# The Dark Knight     185.0   1006.0  Millions      USD  English   16   821.0
# Jurassic Park        63.0   1046.0  Millions      USD  English   31   983.0
# Parasite             15.5    263.1  Millions      USD  English    5   247.6
# Avengers: Endgame   400.0   2798.0  Millions      USD  English    5  2398.0

# %%
df.iloc[2]
# Out:
# industry             Hollywood
# release_year              2013
# imdb_rating                6.8
# studio          Marvel Studios
# budget                     165
# revenue                  644.8
# unit                  Millions
# currency                   USD
# language               English
# age                         11
# profit                   479.8
# Name: Thor: The Dark World , dtype: object

# %%
df.reset_index(inplace=True)
df.tail(5)
# Out:
#                         title   industry  release_year  imdb_rating  \
# 32                  Shershaah  Bollywood          2021          8.4
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language  age  \
# 32   Dharma Productions   500.0    950.0  Millions      INR    Hindi    3
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada    2
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu    3
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu    2
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu    9
#
#     profit
# 32   450.0
# 33    11.5
# 34     1.6
# 35     6.5
# 36     4.7

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)
